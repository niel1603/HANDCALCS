# %%
import handcalcs
from handcalcs.decorator import handcalc
from handcalcs import  render

handcalcs.set_option("math_environment_start", "aligned")
handcalcs.set_option("math_environment_end", "aligned")

handcalcs.set_option("display_precision", 2)
handcalcs.set_option("param_columns", 1)


handcalcs.set_option("latex_block_start", "$$")
handcalcs.set_option("latex_block_end", "$$")

handcalcs.set_option("preferred_string_formatter", "L")

import forallpeople as fp
fp.environment("structural")
m   = fp.m
mm  = fp.mm
kN  = fp.kN
MPa = fp.MPa
GPa = fp.GPa

# %% [markdown]
# ## Design Load LRFD

# %%
# %%render params
# M_u = 860.9076 * kN * m
# T_u = 90.743688 * kN
# V_u = 203.728476 * kN
# V_uc = 87.185112 * kN
# Out:
# $$
# \begin{aligned}
# M_{u} &= 860.91\ \mathrm{kN} \cdot \mathrm{m} \;
# \\[10pt]
#  T_{u} &= 90.74\ \mathrm{kN} \;
# \\[10pt]
#  V_{u} &= 203.73\ \mathrm{kN} \;
# \\[10pt]
#  V_{uc} &= 87.19\ \mathrm{kN} \;
# \\[10pt]
# \end{aligned}
# $$

# %% [markdown]
# ## Material Properties

# %%
# %%render param
# ## Steel
# E = (200 * GPa)
#
# ## Beam and column
# F_ybc = (344.738 * MPa)
# F_ubc = (448.1594 * MPa)
#
# ## Plate
# F_yp = (344.738 * MPa)
# F_up = (448.1594 * MPa)
#
# ## Stiffener
# F_ys = (344.738 * MPa)
# F_us = (448.1594 * MPa)
#
# ## Bolt
# F_nt = (779.10788 * MPa)
# F_nv = (468.84368 * MPa)
#
# ## Bolt pretension force
# # For grade A490 bolt according to AISC Specification Table J3.1
# T_b = (453.71844 * kN)
# Out:
# $$
# \begin{aligned}
# \hspace{4em}\text{\textbf{\small Steel}}\\\\[10pt]
#  E &= 200.00\ \mathrm{GPa} \;
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Beam and column}}\\\\[10pt]
#  F_{ybc} &= 344.74\ \mathrm{MPa} \;
# \\[10pt]
#  F_{ubc} &= 448.16\ \mathrm{MPa} \;
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Plate}}\\\\[10pt]
#  F_{yp} &= 344.74\ \mathrm{MPa} \;
# \\[10pt]
#  F_{up} &= 448.16\ \mathrm{MPa} \;
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Stiffener}}\\\\[10pt]
#  F_{ys} &= 344.74\ \mathrm{MPa} \;
# \\[10pt]
#  F_{us} &= 448.16\ \mathrm{MPa} \;
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Bolt}}\\\\[10pt]
#  F_{nt} &= 779.11\ \mathrm{MPa} \;
# \\[10pt]
#  F_{nv} &= 468.84\ \mathrm{MPa} \;
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Bolt pretension force}}\\\\[10pt]
#  T_{b} &= 453.72\ \mathrm{kN} \;
# \\[10pt]
# \end{aligned}
# $$

# %% [markdown]
# ## Geometry Properties

# %%
# %%render param
#
# ## Beam
# d_b = 612.14 * mm # web height
# b_bf = 229.108 * mm # flange width
# t_bw = 11.938 * mm # web thick
# t_bf = 19.558 * mm # flange thick
#
# ## Column
# d_c = 360.68 * mm # web height
# b_cf = 370.84 * mm # flange width
# t_cw = 12.319 * mm # web thick
# t_cf = 19.812 * mm # flange thick
# k_des = 35.052 * mm # fillet distance used in production
#
# ## Plate
# b_p = 228.6 * mm # width
# t_p = 22.225 * mm # thickness
#
# ## Bolt
# d_bolt = 31.75 * mm # diameter
# d_hole = d_bolt + 3.175 * mm # hole diameter
#
# ## Bolt configuration
# g = 146.05 * mm # gauge
# p_ext = 114.3 * mm # top plate to beam
# d_e = 44.45 * mm # edge distance
# p_fo = 69.85 * mm # flange outer bolt
# p_fi = 50.8 * mm # flange inner bolt
# d_p = 841.375 * mm # bolt group height
#
# ## Stiffener
# t_s = 12.7 * mm # thickness
# L_st = 203.2 * mm # length
# h_st = 114.3 * mm # height
# Out:
# $$
# \begin{aligned}
# \hspace{4em}\text{\textbf{\small Beam}}\\\\[10pt]
#  d_{b} &= 612.14\ \mathrm{mm} \; \;\textrm{(web height)}
# \\[10pt]
#  b_{bf} &= 229.11\ \mathrm{mm} \; \;\textrm{(flange width)}
# \\[10pt]
#  t_{bw} &= 11.94\ \mathrm{mm} \; \;\textrm{(web thick)}
# \\[10pt]
#  t_{bf} &= 19.56\ \mathrm{mm} \; \;\textrm{(flange thick)}
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Column}}\\\\[10pt]
#  d_{c} &= 360.68\ \mathrm{mm} \; \;\textrm{(web height)}
# \\[10pt]
#  b_{cf} &= 370.84\ \mathrm{mm} \; \;\textrm{(flange width)}
# \\[10pt]
#  t_{cw} &= 12.32\ \mathrm{mm} \; \;\textrm{(web thick)}
# \\[10pt]
#  t_{cf} &= 19.81\ \mathrm{mm} \; \;\textrm{(flange thick)}
# \\[10pt]
#  k_{des} &= 35.05\ \mathrm{mm} \; \;\textrm{(fillet distance used in production)}
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Plate}}\\\\[10pt]
#  b_{p} &= 228.60\ \mathrm{mm} \; \;\textrm{(width)}
# \\[10pt]
#  t_{p} &= 22.23\ \mathrm{mm} \; \;\textrm{(thickness)}
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Bolt}}\\\\[10pt]
#  d_{bolt} &= 31.75\ \mathrm{mm} \; \;\textrm{(diameter)}
# \\[10pt]
#  d_{hole} &= 34.92\ \mathrm{mm} \; \;\textrm{(hole diameter)}
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Bolt configuration}}\\\\[10pt]
#  g &= 146.05\ \mathrm{mm} \; \;\textrm{(gauge)}
# \\[10pt]
#  p_{ext} &= 114.30\ \mathrm{mm} \; \;\textrm{(top plate to beam)}
# \\[10pt]
#  d_{e} &= 44.45\ \mathrm{mm} \; \;\textrm{(edge distance)}
# \\[10pt]
#  p_{fo} &= 69.85\ \mathrm{mm} \; \;\textrm{(flange outer bolt)}
# \\[10pt]
#  p_{fi} &= 50.80\ \mathrm{mm} \; \;\textrm{(flange inner bolt)}
# \\[10pt]
#  d_{p} &= 841.38\ \mathrm{mm} \; \;\textrm{(bolt group height)}
# \\[10pt]
#  \hspace{4em}\text{\textbf{\small Stiffener}}\\\\[10pt]
#  t_{s} &= 12.70\ \mathrm{mm} \; \;\textrm{(thickness)}
# \\[10pt]
#  L_{st} &= 203.20\ \mathrm{mm} \; \;\textrm{(length)}
# \\[10pt]
#  h_{st} &= 114.30\ \mathrm{mm} \; \;\textrm{(height)}
# \\[10pt]
# \end{aligned}
# $$

# %% [markdown]
# #### Calculation

# %%
# %%render intertext
# ## 1. The distance from the centerline of the compression flange to the bolt lines
#
# ## 1.1 Calculate distance
# h_1 = d_b - (t_bf / 2) + p_fo
#
# h_2 = d_b - (3 * t_bf / 2) - p_fi
#
# ## 1.2 Check base plate effective width
# b_p_limit = b_bf + max(t_p, 25.4 * mm)
# if b_p <= b_p_limit : b_p_eff = b_p
# elif b_p > b_p_limit : b_p_eff = b_p_limit
#
# ## 1.3 Check bolt gage
# b_bf_limit = b_bf
# if b_bf >= b_bf_limit : b_bf = b_bf_limit # OK
# elif b_bf < b_bf_limit : b_bf = b_bf_limit # NOT OK
# Out:
# ## 1. The distance from the centerline of the compression flange to the bolt lines
#
# ### 1.1 Calculate distance
#
# $$
# \begin{aligned}
# h_{1} &= d_{b} - \left( \frac{ t_{bf} }{ 2 } \right) + p_{fo} \\&= 612.14\ \mathrm{mm} - \left( \frac{ 19.56\ \mathrm{mm} }{ 2 } \right) + 69.85\ \mathrm{mm} \\&= 672.21\ \mathrm{mm}
#
# h_{2} &= d_{b} - \left( 3 \cdot \frac{ t_{bf} }{ 2 } \right) - p_{fi} \\&= 612.14\ \mathrm{mm} - \left( 3 \cdot \frac{ 19.56\ \mathrm{mm} }{ 2 } \right) - 50.80\ \mathrm{mm} \\&= 532.00\ \mathrm{mm}
# \end{aligned}
# $$
#
# ### 1.2 Check base plate effective width
#
# $$
# \begin{aligned}
# b_{p_{limit}} &= b_{bf} + \operatorname{max} \left( t_{p} ,\  25.4 \cdot \mathrm{mm} \right) \\&= 229.11\ \mathrm{mm} + \operatorname{max} \left( 22.23\ \mathrm{mm} ,\  25.4 \cdot 1.00\ \mathrm{mm} \right) \\&= 254.51\ \mathrm{mm}
#
# &\text{Since, } b_{p} \leq b_{p_{limit}} \rightarrow \left( 228.60\ \mathrm{mm} \leq 254.51\ \mathrm{mm} \right) :   \\[10pt]
# b_{p_{eff}} &= 228.60\ \mathrm{mm} \;
# \end{aligned}
# $$
#
# ### 1.3 Check bolt gage
#
# $$
# \begin{aligned}
# b_{bf_{limit}} &= 229.11\ \mathrm{mm} \;
#
# &\text{Since, } b_{bf} \geq b_{bf_{limit}} \rightarrow \left( 229.11\ \mathrm{mm} \geq 229.11\ \mathrm{mm} \right) : \; \;\textrm{(OK)} \\[10pt]
# b_{bf} &= 229.11\ \mathrm{mm} \;
# \end{aligned}
# $$

# %%
# %%tex intertext
# ## 1. The distance from the centerline of the compression flange to the bolt lines
#
# ## 1.1 Calculate distance
# h_1 = d_b - (t_bf / 2) + p_fo
#
# h_2 = d_b - (3 * t_bf / 2) - p_fi
#
# ## 1.2 Check base plate effective width
# b_p_limit = b_bf + max(t_p, 25.4 * mm)
# if b_p <= b_p_limit : b_p_eff = b_p
# elif b_p > b_p_limit : b_p_eff = b_p_limit
#
# ## 1.3 Check bolt gage
# b_bf_limit = b_bf
# if b_bf >= b_bf_limit : b_bf = b_bf_limit # OK
# elif b_bf < b_bf_limit : b_bf = b_bf_limit # NOT OK
# Out:
# ## 1. The distance from the centerline of the compression flange to the bolt lines
#
# ### 1.1 Calculate distance
#
# $$
# \begin{aligned}
# h_{1} &= d_{b} - \left( \frac{ t_{bf} }{ 2 } \right) + p_{fo} \\&= 612.14\ \mathrm{mm} - \left( \frac{ 19.56\ \mathrm{mm} }{ 2 } \right) + 69.85\ \mathrm{mm} \\&= 672.21\ \mathrm{mm}
#
# h_{2} &= d_{b} - \left( 3 \cdot \frac{ t_{bf} }{ 2 } \right) - p_{fi} \\&= 612.14\ \mathrm{mm} - \left( 3 \cdot \frac{ 19.56\ \mathrm{mm} }{ 2 } \right) - 50.80\ \mathrm{mm} \\&= 532.00\ \mathrm{mm}
# \end{aligned}
# $$
#
# ### 1.2 Check base plate effective width
#
# $$
# \begin{aligned}
# b_{p_{limit}} &= b_{bf} + \operatorname{max} \left( t_{p} ,\  25.4 \cdot \mathrm{mm} \right) \\&= 229.11\ \mathrm{mm} + \operatorname{max} \left( 22.23\ \mathrm{mm} ,\  25.4 \cdot 1.00\ \mathrm{mm} \right) \\&= 254.51\ \mathrm{mm}
#
# &\text{Since, } b_{p} \leq b_{p_{limit}} \rightarrow \left( 228.60\ \mathrm{mm} \leq 254.51\ \mathrm{mm} \right) :   \\[10pt]
# b_{p_{eff}} &= 228.60\ \mathrm{mm} \;
# \end{aligned}
# $$
#
# ### 1.3 Check bolt gage
#
# $$
# \begin{aligned}
# b_{bf_{limit}} &= 229.11\ \mathrm{mm} \;
#
# &\text{Since, } b_{bf} \geq b_{bf_{limit}} \rightarrow \left( 229.11\ \mathrm{mm} \geq 229.11\ \mathrm{mm} \right) : \; \;\textrm{(OK)} \\[10pt]
# b_{bf} &= 229.11\ \mathrm{mm} \;
# \end{aligned}
# $$

# %% [markdown]
# $$
# \begin{array}{l}
# % --- Header ---
# \hspace{-5em}\text{\textbf{\Large 1. The distance from the centerline of the compression flange to the bolt lines}} \\[8pt]
#
# % --- Subheader ---
# \hspace{-5em}\text{\textbf{\large 1.1 Calculate distance}} \\[10pt]
#
# % --- Description paragraph ---
# \text{This section evaluates the effective distance from the compression flange centerline}
# \\
# \text{to the bolt lines based on the beam geometry and flange thickness.}
# \\[12pt]
#
# % --- Explanation / logic ---
# \text{Since, } b_p \le b_{p_{\text{limit}}}
# \;\rightarrow\;
# (228.60\ \mathrm{mm} \le 254.51\ \mathrm{mm}) \\[12pt]
#
# % --- Equation ---
# \begin{alignedat}{2}
# b_{p_{\text{eff}}} &{}= 228.60\ \mathrm{mm}
# \end{alignedat}
# \end{array}
# $$
